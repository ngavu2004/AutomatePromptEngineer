# %% [markdown]
# # README
# - Download Ollama
# - Run the following commands in command prompt in order:
# -   ollama pull llama3
# -   ollama serve

# %%
# %pip install langchain pandas beeprint
# Out:
# Collecting langchain
#   Using cached langchain-0.3.3-py3-none-any.whl.metadata (7.1 kB)
# Collecting pandas
#   Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: beeprint in c:\users\thiquynh\documents\vu\automation_venv\lib\site-packages (2.4.11)
# Collecting PyYAML>=5.3 (from langchain)
#   Using cached PyYAML-6.0.2-cp312-cp312-win_amd64.whl.metadata (2.1 kB)
# Collecting SQLAlchemy<3,>=1.4 (from langchain)
#   Using cached SQLAlchemy-2.0.35-cp312-cp312-win_amd64.whl.metadata (9.9 kB)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain)
#   Downloading aiohttp-3.10.10-cp312-cp312-win_amd64.whl.metadata (7.8 kB)
# Collecting langchain-core<0.4.0,>=0.3.10 (from langchain)
#   Using cached langchain_core-0.3.10-py3-none-any.whl.metadata (6.3 kB)
# Collecting langchain-text-splitters<0.4.0,>=0.3.0 (from langchain)
#   Using cached langchain_text_splitters-0.3.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain)
#   Downloading langsmith-0.1.134-py3-none-any.whl.metadata (13 kB)
# Collecting numpy<2.0.0,>=1.26.0 (from langchain)
#   Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
# Collecting pydantic<3.0.0,>=2.7.4 (from langchain)
#   Using cached pydantic-2.9.2-py3-none-any.whl.metadata (149 kB)
# Collecting requests<3,>=2 (from langchain)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting tenacity!=8.4.0,<9.0.0,>=8.1.0 (from langchain)
#   Using cached tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\thiquynh\documents\vu\automation_venv\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: urwid in c:\users\thiquynh\documents\vu\automation_venv\lib\site-packages (from beeprint) (2.6.15)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Using cached aiohappyeyeballs-2.4.3-py3-none-any.whl.metadata (6.1 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Using cached aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting attrs>=17.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Using cached attrs-24.2.0-py3-none-any.whl.metadata (11 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Using cached frozenlist-1.4.1-cp312-cp312-win_amd64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Using cached multidict-6.1.0-cp312-cp312-win_amd64.whl.metadata (5.1 kB)
# Collecting yarl<2.0,>=1.12.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Using cached yarl-1.14.0-cp312-cp312-win_amd64.whl.metadata (54 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.4.0,>=0.3.10->langchain)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\thiquynh\documents\vu\automation_venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.10->langchain) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\thiquynh\documents\vu\automation_venv\lib\site-packages (from langchain-core<0.4.0,>=0.3.10->langchain) (4.12.2)
# Collecting httpx<1,>=0.23.0 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Using cached httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Using cached orjson-3.10.7-cp312-none-win_amd64.whl.metadata (51 kB)
# Collecting requests-toolbelt<2.0.0,>=1.0.0 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.23.4 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Using cached pydantic_core-2.23.4-cp312-none-win_amd64.whl.metadata (6.7 kB)
# Requirement already satisfied: six>=1.5 in c:\users\thiquynh\documents\vu\automation_venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Collecting charset-normalizer<4,>=2 (from requests<3,>=2->langchain)
#   Using cached charset_normalizer-3.4.0-cp312-cp312-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2->langchain)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2->langchain)
#   Using cached urllib3-2.2.3-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2->langchain)
#   Using cached certifi-2024.8.30-py3-none-any.whl.metadata (2.2 kB)
# Collecting greenlet!=0.4.17 (from SQLAlchemy<3,>=1.4->langchain)
#   Using cached greenlet-3.1.1-cp312-cp312-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: wcwidth in c:\users\thiquynh\documents\vu\automation_venv\lib\site-packages (from urwid->beeprint) (0.2.13)
# Collecting anyio (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain)
#   Using cached anyio-4.6.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain)
#   Using cached httpcore-1.0.6-py3-none-any.whl.metadata (21 kB)
# Collecting sniffio (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain)
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.10->langchain)
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting propcache>=0.2.0 (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain)
#   Using cached propcache-0.2.0-cp312-cp312-win_amd64.whl.metadata (7.9 kB)
# Using cached langchain-0.3.3-py3-none-any.whl (1.0 MB)
# Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
# Downloading aiohttp-3.10.10-cp312-cp312-win_amd64.whl (379 kB)
# Using cached langchain_core-0.3.10-py3-none-any.whl (404 kB)
# Using cached langchain_text_splitters-0.3.0-py3-none-any.whl (25 kB)
# Downloading langsmith-0.1.134-py3-none-any.whl (295 kB)
# Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl (15.5 MB)
# Using cached pydantic-2.9.2-py3-none-any.whl (434 kB)
# Using cached pydantic_core-2.23.4-cp312-none-win_amd64.whl (1.9 MB)
# Using cached pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Using cached PyYAML-6.0.2-cp312-cp312-win_amd64.whl (156 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached SQLAlchemy-2.0.35-cp312-cp312-win_amd64.whl (2.1 MB)
# Using cached tenacity-8.5.0-py3-none-any.whl (28 kB)
# Using cached tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# Using cached aiohappyeyeballs-2.4.3-py3-none-any.whl (14 kB)
# Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached attrs-24.2.0-py3-none-any.whl (63 kB)
# Using cached certifi-2024.8.30-py3-none-any.whl (167 kB)
# Using cached charset_normalizer-3.4.0-cp312-cp312-win_amd64.whl (102 kB)
# Using cached frozenlist-1.4.1-cp312-cp312-win_amd64.whl (50 kB)
# Using cached greenlet-3.1.1-cp312-cp312-win_amd64.whl (299 kB)
# Using cached httpx-0.27.2-py3-none-any.whl (76 kB)
# Using cached httpcore-1.0.6-py3-none-any.whl (78 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Using cached multidict-6.1.0-cp312-cp312-win_amd64.whl (28 kB)
# Using cached orjson-3.10.7-cp312-none-win_amd64.whl (137 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached urllib3-2.2.3-py3-none-any.whl (126 kB)
# Using cached yarl-1.14.0-cp312-cp312-win_amd64.whl (83 kB)
# Using cached jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Using cached propcache-0.2.0-cp312-cp312-win_amd64.whl (44 kB)
# Using cached anyio-4.6.0-py3-none-any.whl (89 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Installing collected packages: pytz, urllib3, tzdata, tenacity, sniffio, PyYAML, pydantic-core, propcache, orjson, numpy, multidict, jsonpointer, idna, h11, greenlet, frozenlist, charset-normalizer, certifi, attrs, annotated-types, aiohappyeyeballs, yarl, SQLAlchemy, requests, pydantic, pandas, jsonpatch, httpcore, anyio, aiosignal, requests-toolbelt, httpx, aiohttp, langsmith, langchain-core, langchain-text-splitters, langchain
# Successfully installed PyYAML-6.0.2 SQLAlchemy-2.0.35 aiohappyeyeballs-2.4.3 aiohttp-3.10.10 aiosignal-1.3.1 annotated-types-0.7.0 anyio-4.6.0 attrs-24.2.0 certifi-2024.8.30 charset-normalizer-3.4.0 frozenlist-1.4.1 greenlet-3.1.1 h11-0.14.0 httpcore-1.0.6 httpx-0.27.2 idna-3.10 jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.3.3 langchain-core-0.3.10 langchain-text-splitters-0.3.0 langsmith-0.1.134 multidict-6.1.0 numpy-1.26.4 orjson-3.10.7 pandas-2.2.3 propcache-0.2.0 pydantic-2.9.2 pydantic-core-2.23.4 pytz-2024.2 requests-2.32.3 requests-toolbelt-1.0.0 sniffio-1.3.1 tenacity-8.5.0 tzdata-2024.2 urllib3-2.2.3 yarl-1.14.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install beeprint
# Out:
# Requirement already satisfied: beeprint in c:\users\thiquynh\documents\vu\.venv\lib\site-packages (2.4.11)
# Requirement already satisfied: urwid in c:\users\thiquynh\documents\vu\.venv\lib\site-packages (from beeprint) (2.6.15)
# Requirement already satisfied: typing-extensions in c:\users\thiquynh\documents\vu\.venv\lib\site-packages (from urwid->beeprint) (4.12.2)
# Requirement already satisfied: wcwidth in c:\users\thiquynh\documents\vu\.venv\lib\site-packages (from urwid->beeprint) (0.2.13)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain import PromptTemplate
from langchain_core.prompts.few_shot import FewShotPromptTemplate
import pandas as pd
import numpy as np
import os
from beeprint import pp
import re
import requests

# %%
# The dictionary including every grading criteria for each section in the input 
criteria_dict = {
    "Description": [
        "1. Does the name of the \"Project Name:\" attribute specified in the file?",
        "2. Does the name of the \"Clinic:\" attribute specified in the file?",
        "3. Does the name of the \"Process:\" attribute specified in the file?",
        "4. Does the name of the \"TIP 2.0 Process Milestone:\" attribute specified in the file?",
        "5. Does the name of the \"TIP 2.0 Process Milestone:\" attribute provide specific process milestone details?",
        "6. Does the value of the \"Project Description / Purpose\" attribute include a brief description of the project?",
        "7. Does the value of the \"Project Description / Purpose\" attribute include a sentence that explicitly state the purpose of the project?",
        "8. Does the value of the \"Project Description / Purpose\" attribute include a detailed expected results from the project?"
    ],
    "Overview": [
        "1. Does the value of the \"Problem Summary:\" attribute include a detailed (at least 1 sentence) and logical problem statement (relating to the project description/purpose)?",
        "2. Does the value of the \"Desired Outcome(s):\" attribute include a at least 1 sentence explicitly talking about the expected results/desired outcomes?",
        "3. Does the value of the \"Benefits:\" attribute include a least 1 sentence explicitly talking about the benefits of this project?"
    ],
    "Timeline": [
        "1. Does the value of the each task list key tasks?",
        "2. Does the value of the each task contain a specific planned completion due dates?"
    ],
    "Scope": [
        "3. Does the value of the \"In Scope Project Objectives\" attribute include an aligned objectives with the project purpose?",
        "4. Does the value of the \"Out of Scope Project Objectives or Activities\" attribute include an aligned objectives with the project purpose?",
        "5. Does the value of the In Scope Project Objectives align with project milestone?"
    ],
    "Team": [
        "1. Does the value of the \"Team Lead:\" attribute contain an individual's name?",
        "2. Does the value of the \"Project Champion:\" attribute contain an individual's name?",
        "3. Does the value of the \"Process Owner:\" attribute contain an individual's name?",
        "4. Does the value of the \"Process Manager:\" attribute contain an individual's name?",
        "5. Does the value of the \"Stakeholders\" \"stakeholder\" attribute contain an individual's name?",
        "6. Do the \"Stakeholders\" contain values for the attributes: title, department, and organization?",
        "7. Does the value of the \"Project Team Members\" \"Name\" attribute contain an individual's name?",
        "8. Do the \"Project Team Members\" contain role values for the \"Team role\" attribute?"
    ]

}

# %%
# The prompts including the examples of good and bad submission for each section
grading_prompts = PromptTemplate.from_template("""
You are grading a project {section}. This is the criteria: {criteria}. Give the grade in range 0 to 5. If the information specified in
                                               criteria was not provided in the submission, even if the criteria is partially met, grade it 0. If the submission include the information needed in criteria,
                                                grade it 3. If the information is very detailed, more than 2 sentences, grade it 5.
                                               Output with format: Grade: [grade]. Comment: [comment]


Grade this submission:
{input}
""")

# %%
# Grading prompts without example
grading_prompts_v2 = {
    "Milestone": (PromptTemplate.from_template("""
You are grading a project milestone. It should  {criteria}. Compare the submission’s milestone with the example with a grade of 100 and the example with a grade of 50. The highest grade possible is 100 and the lowest grade possible is 0. Output with format: Grade: [grade]. Comment: [comment]


Grade this submission:
{milestone}
""")),

   "Description":  (PromptTemplate.from_template("""
You are grading a project description. It should  {criteria}. Compare the submission’s Project Description / Purpose with the example with grade of 100 and the example with a grade of 50. The highest grade possible is 100 and the lowest grade possible is 0. Output with format: Grade: [grade]. Comment: [comment]

Grade this submission:
{description}
""")),

"Overview": (PromptTemplate.from_template("""
You are grading a project overview. This project description is also provided. It should {criteria}.Compare the submission with the example with a grade of 100 and the example with a grade of 50. The highest grade possible is 100 and the lowest grade possible is 0. Output with format: Grade: [grade]. Comment: [comment]

Grade this submission:
{overview}
""")),

"Timeline": (PromptTemplate.from_template("""
You are grading a project timeline. It should  {criteria}. Compare the submission with the example with a grade of 100 and the example with a grade of 50. The highest grade possible is 100 and the lowest grade possible is 0. Output with format: Grade: [grade]. Comment: [comment]

Grade this submission:
{timeline}
""")),

"Scope": (PromptTemplate.from_template("""
You are grading a project scope. It should {criteria}. Compare the submission with the example with a grade of 100 and the example with a grade of 50. The highest grade possible is 100 and the lowest grade possible is 0. Output with format: Grade: [grade]. Comment: [comment]
Grade this project scope given its project description:
Project description: {description}
Project scope: {scope}
""")),

"Team": (PromptTemplate.from_template("""
You are grading the project team member part. It should {criteria}. Compare the submission with the example with a grade of 100 and the example with a grade of 0. The highest grade possible is 100 and the lowest grade possible is 0. Output with format: Grade: [grade]. Comment: [comment]

Grade this submission:
{team}
"""))
}

# %%
def extract_dictionary_from_text_file(file_path):
    section_dict = {}
    text = open(file_path, 'r').read()
    target_sections = ["Description", "Overview", "Timeline","Scope", "Team"]
    pattern = r'(' + '|'.join(re.escape(name) for name in target_sections) + '):'

    # Find all the section headers and split the text accordingly
    sections = re.split(pattern, text)

    # The first element in sections is either empty or non-useful text before the first header
    sections = sections[1:]  # Skip the first element as it would be empty or non-section text

    # Creating a dictionary to store the section names and their corresponding content

    # Iterate over the list in pairs: section name and its corresponding text
    for i in range(0, len(sections), 2):
        section_name = sections[i].strip()  # Section name (e.g., 'Description')
        section_content = sections[i+1].strip()  # Corresponding content

        if section_name in target_sections:  # Only add the section if it's in the predefined list
            section_dict[section_name] = section_content
    section_dict['Milestone'] = section_dict['Description']
    
    return section_dict

# %% [markdown]
# # Auto generate rubric Class

# %%
real_comment_df = pd.read_csv("auto_grading_trainingset\Simulated_submissions_for_training_LLM.csv")
real_comment_df
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\S'
# <>:1: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\thiquynh\AppData\Local\Temp\ipykernel_37720\3292376348.py:1: SyntaxWarning: invalid escape sequence '\S'
#   real_comment_df = pd.read_csv("auto_grading_trainingset\Simulated_submissions_for_training_LLM.csv")
#        Filename                      Author  Section  Criteria  Total points  \
# 0     input.txt                    example2      NaN       NaN           6.0
# 1    input2.txt                 Angela Abad      NaN       NaN           5.0
# 2    input3.txt                  Kim Briggs      NaN       NaN           5.0
# 3    input4.txt                    example1      NaN       NaN           6.0
# 4    input5.txt               Yesenia Bravo      NaN       NaN           6.0
# 5    input6.txt                Malca Cortez      NaN       NaN           5.0
# 6    input7.txt                     crystal      NaN       NaN           5.0
# 7    input8.txt                 Sarah Davis      NaN       NaN           5.0
# 8    input9.txt       Jennifer Diaz-Montano      NaN       NaN           3.0
# 9   input10.txt                 Karen Eynon      NaN       NaN           5.0
# 10  input11.txt     Simulated / Caryn Hahne      NaN       NaN           2.0
# 11  input12.txt     Simulated / Nick Thelen      NaN       NaN           1.0
# 12  input13.txt        Simulated / Sonnette      NaN       NaN           2.0
# 13  input14.txt  Simulated / Angela Roumain      NaN       NaN           2.0
# 14  input15.txt  Simulated / Michelle Reyes      NaN       NaN           1.0
# 15  input16.txt    Simulated/ Kolleen Weber      NaN       NaN           0.0
# 16          NaN                         NaN      NaN       NaN           NaN
#
#                                   Reson deduct points
# 0                                                 NaN
# 1   Team missing Project champion and Process manager
# 2   I do not see enough detail on problem summary,...
# 3                                                 NaN
# 4                                                 NaN
# 5                              No project description
# 6            the project milestone doesn't look right
# 7                   the project milestone lack detail
# 8   I do not see enough detail about the project d...
# 9   I do not see enough detail about the project d...
# 10  Fail in Description (lack purpose/expected res...
# 11  Fail in Description (lack name, clinic, milest...
# 12                   Milestone, Timeline, Scope, Team
# 13                Milestone, Description, Scope, Team
# 14  Fail in Scope, Overview (no problem summary), ...
# 15  Team: Lack teamlead, timeline: lack due date, ...
# 16                                                NaN

# %%
real_comment_df['Reson deduct points'].tolist()
# Out:
# [nan,
#  'Team missing Project champion and Process manager',
#  'I do not see enough detail on problem summary, desired outcomes, and benefits.',
#  nan,
#  nan,
#  'No project description',
#  "the project milestone doesn't look right",
#  'the project milestone lack detail',
#  'I do not see enough detail about the project description and purpose statement; I see project tasks but no due dates; The scope objectives do not match the previously stated project purpose. The project scope objectives could simply be "To better address the HRSN needs of patients". The out of scope objective could be "We are not implementing any other platforms".',
#  'I do not see enough detail about the project description and purpose statement. I recommend a clear statement like "The purpose of this project is to implement a ...".',
#  'Fail in Description (lack purpose/expected result), Overview(lack outcomes and benefits), Timeline (lack due date), Team members (lack every fields in team section)',
#  "Fail in Description (lack name, clinic, milestone, description), Overview (doesn't describe the problems), Timeline (lack key tasks), Team members (lack project owner/champion/manager), Milestone",
#  'Milestone, Timeline, Scope, Team',
#  'Milestone, Description, Scope, Team',
#  'Fail in Scope, Overview (no problem summary), Timeline (lack due date), Team members, Milestone',
#  'Team: Lack teamlead, timeline: lack due date, fail everything',
#  nan]

# %%
dict(zip(real_comment_df['Filename'].tolist(),real_comment_df['Reson deduct points'].tolist()))
# Out:
# {'input.txt': nan,
#  'input2.txt': 'Team missing Project champion and Process manager',
#  'input3.txt': 'I do not see enough detail on problem summary, desired outcomes, and benefits.',
#  'input4.txt': nan,
#  'input5.txt': nan,
#  'input6.txt': 'No project description',
#  'input7.txt': "the project milestone doesn't look right",
#  'input8.txt': 'the project milestone lack detail',
#  'input9.txt': 'I do not see enough detail about the project description and purpose statement; I see project tasks but no due dates; The scope objectives do not match the previously stated project purpose. The project scope objectives could simply be "To better address the HRSN needs of patients". The out of scope objective could be "We are not implementing any other platforms".',
#  'input10.txt': 'I do not see enough detail about the project description and purpose statement. I recommend a clear statement like "The purpose of this project is to implement a ...".',
#  'input11.txt': 'Fail in Description (lack purpose/expected result), Overview(lack outcomes and benefits), Timeline (lack due date), Team members (lack every fields in team section)',
#  'input12.txt': "Fail in Description (lack name, clinic, milestone, description), Overview (doesn't describe the problems), Timeline (lack key tasks), Team members (lack project owner/champion/manager), Milestone",
#  'input13.txt': 'Milestone, Timeline, Scope, Team',
#  'input14.txt': 'Milestone, Description, Scope, Team',
#  'input15.txt': 'Fail in Scope, Overview (no problem summary), Timeline (lack due date), Team members, Milestone',
#  'input16.txt': 'Team: Lack teamlead, timeline: lack due date, fail everything',
#  nan: nan}

# %%
# The prompts including the examples of good and bad submission for each section
rubric_prompts = PromptTemplate.from_template("""
Based on a comment from a real grader, you are generating the grades for section {section} with criteria {criteria} . 
                                               Give the grade in range 0 to 5. If the comment is None, give this criteria
                                               a grade of 5. If the comment mention this section or this criteria, give this criteria a grade of 0.
                                               Output with format: Grade: [grade]. Comment: [comment]


This is the comment:
{input}
""")

# %%
class Rubric():
    def __init__(self,inputfile_folder_path,real_comment_file_path,rubric_prompts,rubric_criteria):
        self.root_dir = inputfile_folder_path
        self.file_list = os.listdir(inputfile_folder_path),
        self.rubric_prompts = rubric_prompts,
        self.rubric_criteria = rubric_criteria,
        self.sections = ["Description", "Overview", "Timeline","Scope","Team"]
        self.rubric = pd.DataFrame({
            "filename": [],
            "Section": [],
            "Criteria": [],
            "Real_Grade": []
        }),
        self.real_comment_df = pd.read_csv(real_comment_file_path).fillna('None')
        self.comment_dict = dict(zip(self.real_comment_df['Filename'].tolist(),self.real_comment_df['Reson deduct points'].tolist()))

    def get_score(self,prompt):
        url = "http://localhost:11434/api/chat"
        # The JSON data that would be sent in the POST request
        data = {
            "model": "llama3",
            "messages": [
                { "role": "user", "content": prompt }
            ],
            "stream": False
        }
        # Send the POST request
        response = requests.post(url, json=data)

        # Check if the request was successful
        if response.status_code == 200:
            # Return the JSON response
            print(response.json()["message"]["content"])
            pattern = r"Grade:\s*([A-Za-z0-9\+]+)\s*(.*)"
            match = re.search(pattern, response.json()["message"]["content"])
            return [match.group(1),match.group(2)]
            
        else:
            print(f"Error: {response.status_code}, {response.text}")
            return "-1"
        
    def generatePrompt(self, section, criteria, comment):
        prompt = grading_prompts.format(
            criteria=criteria,
            section=section,
            input=comment
            )
        # print(prompt)
        return prompt

    def get_y_test(self):
        for filename in self.file_list[0]:
            print(f"File name: {filename}")
            comment = self.comment_dict[filename]
            for section in self.sections:
                for criteria in self.rubric_criteria[0][section]:
                    current_prompt = self.generatePrompt(section,criteria,comment)
                    [score,comment] = self.get_score(current_prompt)
                    self.rubric[0].loc[len(self.rubric[0].index)] = [filename,section,criteria,score]
                    print(f"Finished {len(self.rubric[0].index)}/{len(self.file_list[0])}")
        print("Finished generating real grade.")
        return self.rubric[0]

# %%
rubric = Rubric(inputfile_folder_path="auto_grading_trainingset/input_files/",
                real_comment_file_path="auto_grading_trainingset\Simulated_submissions_for_training_LLM.csv",
                rubric_prompts=rubric_prompts,
                rubric_criteria=criteria_dict)
real_grade_df = rubric.get_y_test()
real_grade_df
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\S'
# <>:2: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\thiquynh\AppData\Local\Temp\ipykernel_37720\1915370344.py:2: SyntaxWarning: invalid escape sequence '\S'
#   real_comment_file_path="auto_grading_trainingset\Simulated_submissions_for_training_LLM.csv",
# File name: input.txt
# Grade: 5. Comment: None
# Finished 1/15
# Grade: 5. Comment: .
# Finished 2/15
# Grade: 5. Comment: .
# Finished 3/15
# Grade: 5. Comment: .
# Finished 4/15
# Grade: 5. Comment: .
# Finished 5/15
# Grade: 5. Comment: .
# Finished 6/15
# Grade: 5. Comment: .
# Finished 7/15
# Grade: 5. Comment: .
# Finished 8/15
# Grade: 5. Comment: .
# Finished 9/15
# Grade: 5. Comment: .
# Finished 10/15
# Grade: 5
# Comment: .
# Finished 11/15
# Since the comment is blank (i.e., None), I will assign a grade of 5 to this criterion.
#
# Output:
# Grade: 5
# Comment: .
# Finished 12/15
# Grade: 5. Comment: .
# Finished 13/15
# Grade: 5. Comment: None
# Finished 14/15
# Here is the output:
#
# Grade: 5
# Comment: . Comment: None
# Finished 15/15
# Grade: 5. Comment: None
# Finished 16/15
# Grade: 5. Comment: . None
# Finished 17/15
# Grade: 5
# Comment: None
# Finished 18/15
# Grade: 5
# Comment: None
# Finished 19/15
# Grade: 5
# Comment: None
# Finished 20/15
# Grade: 5
# Comment: None
# Finished 21/15
# Grade: 5
# Comment: None
# Finished 22/15
# Grade: 5
# Comment: None
# Finished 23/15
# Grade: 5. Comment: None
# Finished 24/15
# File name: input10.txt
# Grade: 0. Comment: The comment mentions this section, so it gets a grade of 0.
# Finished 25/15
# Grade: 0. Comment: The comment mentions this section.
# Finished 26/15
# Grade: 0
# Comment: The comment mentions this section.
# Finished 27/15
# Grade: 0. Comment: The comment mentions this section.
# Finished 28/15
# Grade: 0
# Comment: The comment mentions this section.
# Finished 29/15
# Grade: 0. Comment: The comment mentions this section.
# Finished 30/15
# Grade: 0
# Comment: The comment mentions this section.
# Finished 31/15
# Grade: 0. Comment: The comment mentions this section.
# Finished 32/15
# Grade: 0. Comment: The comment mentions this section.
# Finished 33/15
# Grade: 0. Comment: The comment mentions this section.
# Finished 34/15
# Grade: 0. Comment: The comment mentions this section.
# Finished 35/15
# Grade: 0. Comment: The comment mentions this section.
# Finished 36/15
# Grade: 0
# Comment: The comment mentions this section.
# Finished 37/15
# Grade: 0. Comment: The comment mentions this section.
# Finished 38/15
# Grade: 0
# Comment: The comment mentions this section.
# Finished 39/15
# Grade: 0. Comment: The comment mentions this section.
# Finished 40/15
# Grade: 0
# Comment: The comment mentions this section.
# Finished 41/15
# Grade: 0.
# Comment: The comment mentions this section.
# Finished 42/15
# Grade: 5. Comment: .
# Finished 43/15
# Grade: 5. Comment: .
# Finished 44/15
# Grade: 5. Comment: .
# Finished 45/15
# Grade: 5. Comment: .
# Finished 46/15
# Since there is no comment provided, I will assume that it does not specifically mention this section or this criterion. Therefore, I will give this criterion a grade based on its presence or absence.
#
# Grade: 5
# Comment: .
# Finished 47/15
# Grade: 5. Comment: .
# Finished 48/15
# File name: input11.txt
# Grade: 0. Comment: The comment mentions "Description" which means this criterion was not met, hence grade 0.
# Finished 49/15
# Grade: 0. Comment: The comment mentions "Description" which means this criterion was not met.
# Finished 50/15
# Grade: 0
# Comment: The comment mentions "Description" which means this criterion was not met.
# Finished 51/15
# Grade: 0. Comment: The comment mentions "Description" which means this criterion was not met.
# Finished 52/15
# Grade: 0
# Comment: The comment mentions "Description" which means this criterion was not met.
# Finished 53/15
# Grade: 0. Comment: The comment mentions "Description" which means this criterion was not met.
# Finished 54/15
# Grade: 0
# Comment: The comment mentions "Description" which means this criterion was not met.
# Finished 55/15
# Grade: 0. Comment: The comment mentions "Description" which means this criterion was not met.
# Finished 56/15
# Grade: 0. Comment: The comment mentions "Description" which means this criterion was not met.
# Finished 57/15
# Grade: 0
# Comment: The comment mentions "Description" which means this criterion was not met.
# Finished 58/15
# Grade: 0. Comment: The comment mentions "Description" which means this criterion was not met.
# Finished 59/15
# Grade: 0
# Comment: The comment mentions "Description" which means this criterion was not met.
# Finished 60/15
# Grade: 0. Comment: The comment mentions "Description" which means this criterion was not met.
# Finished 61/15
# Grade: 0. Comment: . The comment mentions "Description" which means this criterion was not met.
# Finished 62/15
# Grade: 0
# Comment: The comment mentions "Description", which implies that the value of the "Out of Scope Project Objectives or Activities" attribute does not include aligned objectives with the project purpose, so the criterion is not met.
# Finished 63/15
# Grade: 0. Comment: The comment mentions "Description", which implies that the value of the "Out of Scope Project Objectives or Activities" attribute does not include aligned objectives with the project purpose, so the criterion is not met.
# Finished 64/15
# Grade: 0. Comment: The comment doesn't mention "Team Lead:" at all, it talks about something else, so I'm giving this criteria a grade of 0.
# Finished 65/15
# Grade: 0
# Comment: The comment doesn't mention "Project Champion:" at all, it talks about something else, so I'm giving this criteria a grade of 0.
# Finished 66/15
# Grade: 0. Comment: The comment doesn't mention "Process Owner:" at all, it talks about something else, so I'm giving this criteria a grade of 0.
# Finished 67/15
# Grade: 0
# Comment: The comment doesn't mention "Process Manager:" at all, it talks about something else, so I'm giving this criteria a grade of 0.
# Finished 68/15
# Grade: 0. Comment: The comment doesn't mention "Process Manager:" at all, it talks about something else, so I'm giving this criteria a grade of 0.
# Finished 69/15
# Grade: 0
# Comment: The comment doesn't mention "Process Manager:" at all, it talks about something else, so I'm giving this criteria a grade of 0.
# Finished 70/15
# Grade: 0. Comment: The comment doesn't mention "Project Team Members" "Name" attribute contain an individual's name, it talks about something else.
# Finished 71/15
# Grade: 5
# Comment: None
# Finished 72/15
# File name: input12.txt
# Grade: 0. Comment: Fail in Description (lack name, clinic, milestone, description)
# Finished 73/15
# Grade: 0. Comment: . Fail in Description (lack name, clinic, milestone, description)
# Finished 74/15
# Grade: 0. Comment: . Fail in Description (lack name, clinic, milestone, description)
# Finished 75/15
# Grade: 0
# Comment: . Fail in Description (lack name, clinic, milestone, description)
# Finished 76/15
# Grade: 0. Comment: . Fail in Description (lack name, clinic, milestone, description)
# Finished 77/15
# Grade: 0. Comment: . Fail in Description (lack name, clinic, milestone, description)
# Finished 78/15
# Grade: 0. Comment: . Fail in Description (lack name, clinic, milestone, description)
# Finished 79/15
# Grade: 0. Comment: . Fail in Description (lack name, clinic, milestone, description)
# Finished 80/15
# Grade: 0. Comment: . Fail in Description (lack name, clinic, milestone, description)
# Finished 81/15
# Since there is no mention of this section or criteria in the comment, I would give it a grade of 5.
#
# Grade: 5. Comment: None mentioned.
# Finished 82/15
# Grade: 5. Comment: None mentioned.
# Finished 83/15
# Here is the output:
#
# Grade: 5
# Comment: None mentioned.
#
# Since the comment is None, I gave the grade a score of 5, indicating that this criteria was not mentioned or evaluated in the comment.
# Finished 84/15
# Grade: 5. Comment: None mentioned.
# Finished 85/15
# Here is the output:
#
# Grade: 5. Comment: None mentioned.
#
# (Note: Since the comment mentions "None", which means nothing was mentioned about this criteria, I gave it a grade of 5)
# Finished 86/15
# Grade: 5. Comment: None mentioned.
# Finished 87/15
# Grade: 5. Comment: None mentioned.
# Finished 88/15
# Grade: 5. Comment: None mentioned.
# Finished 89/15
# Grade: 5
# Comment: None mentioned.
# Finished 90/15
# Grade: 5. Comment: None mentioned.
# Finished 91/15
# Grade: 5. Comment: None mentioned.
# Finished 92/15
# Grade: 5. Comment: None mentioned.
# Finished 93/15
# Grade: 5. Comment: . None mentioned.
# Finished 94/15
# Grade: 5. Comment: None mentioned.
# Finished 95/15
# Grade: 5. Comment: None mentioned.
# Finished 96/15
# File name: input14.txt
# Grade: 0. Comment: Milestone, Description, Scope, Team
# Finished 97/15
# Based on the comment, I generate the grades for Section "Description" with Criteria "Does the name of the 'Clinic:' attribute specified in the file?":
#
# Grade: 0. Comment: Milestone, Description, Scope, Team
# Finished 98/15
# Grade: 0. Comment: . Milestone, Description, Scope, Team
# Finished 99/15
# Grade: 0. Comment: . Milestone, Description, Scope, Team
# Finished 100/15
# Grade: 0. Comment: . Milestone, Description, Scope, Team
# Finished 101/15
# Grade: 5. Comment: . Milestone, Description, Scope, Team
# Finished 102/15
# Grade: 5. Comment: .
# Finished 103/15
# Grade: 5. Comment: .
# Finished 104/15
# Grade: 5. Comment: .
# Finished 105/15
# Grade: 5. Comment: .
# Finished 106/15
# Since the comment is empty (i.e., it's an empty string), I will give the grade for this criteria as:
#
# Grade: 5. Comment: .
#
# (Note that if the comment had mentioned this section or criteria, I would have given a grade of 0.)
# Finished 107/15
# Grade: 5. Comment: .
# Finished 108/15
# Grade: 5. Comment: None
# Finished 109/15
# Grade: 5. Comment: . None
# Finished 110/15
# Grade: 5. Comment: None
# Finished 111/15
# Grade: 5
# Comment: None
# Finished 112/15
# Grade: 5
# Comment: None
# Finished 113/15
# Grade: 5. Comment: None
# Finished 114/15
# Grade: 5
# Comment: None
# Finished 115/15
# Grade: 5
# Comment: None
# Finished 116/15
# Grade: 5. Comment: None
# Finished 117/15
# Grade: 5. Comment: .
# Finished 118/15
# Since the comment is empty (i.e., `''`), I will assign a default grade of 5.
#
# Here's the output:
#
# Grade: 5
# Comment:
# Finished 119/15
# Grade: 5
# Comment: None
# Finished 120/15
# File name: input15.txt
# Grade: 0. Comment: Fail in Scope, Overview (no problem summary), Timeline (lack due date), Team members, Milestone
# Finished 121/15
# Based on the comment, I generate the grade for section "Description" with criteria "Does the name of the 'Clinic:' attribute specified in the file?".
#
# Since the comment mentions "Fail in Scope, Overview (no problem summary), Timeline (lack due date), Team members, Milestone", it does not mention this specific criterion ("Does the name of the 'Clinic:' attribute specified in the file?"), I would give this criterion a grade of 5.
#
# Here is the output:
#
# Grade: 5. Comment: The comment does not mention this criteria at all.
# Finished 122/15
# Grade: 5
# Comment: The comment does not mention this criteria at all.
# Finished 123/15
# Grade: 5
# Comment: The comment does not mention this criteria at all.
# Finished 124/15
# Grade: 5
# Comment: The comment does not mention this criteria at all.
# Finished 125/15
# Grade: 5
# Comment: The comment does not mention this criteria at all.
# Finished 126/15
# Grade: 5. Comment: The comment does not mention this criteria at all.
# Finished 127/15
# Grade: 5. Comment: The comment does not mention this criteria at all.
# Finished 128/15
# Grade: 5
# Comment: None
# Finished 129/15
# Grade: 5. Comment: None
# Finished 130/15
# Grade: 5. Comment: .
# Finished 131/15
# Since the comment is None, I will assign a grade of 5 for the first criterion.
#
# Grade: 5
# Comment: None
# Finished 132/15
# Grade: 5. Comment: None
# Finished 133/15
# Grade: 5. Comment: None
# Finished 134/15
# Grade: 5. Comment: None
# Finished 135/15
# Grade: 5
# Comment: None
# Finished 136/15
# Grade: 5. Comment: None
# Finished 137/15
# Grade: 5
# Comment: None
# Finished 138/15
# Grade: 5. Comment: None
# Finished 139/15
# Grade: 5
# Comment: . None
# Finished 140/15
# Grade: 5. Comment: None
# Finished 141/15
# Grade: 5
# Comment: . Comment: None
# Finished 142/15
# Grade: 5. Comment: None
# Finished 143/15
# Grade: 5. Comment: None
# Finished 144/15
# File name: input16.txt
# Grade: 0. Comment: Team: Lack teamlead, timeline: lack due date, fail everything
# Finished 145/15
# Grade: 0. Comment: The comment explicitly mentions "Description" which means this criteria fails.
# Finished 146/15
# Grade: 0
# Comment: The comment explicitly mentions "Description" which means this criteria fails.
# Finished 147/15
# Grade: 0
# Comment: The comment explicitly mentions "Description" which means this criteria fails.
# Finished 148/15
# Grade: 0
# Comment: The comment explicitly mentions "Description" which means this criteria fails.
# Finished 149/15
# Grade: 0. Comment: The comment explicitly mentions "Description" which means this criteria fails.
# Finished 150/15
# Grade: 0
# Comment: The comment explicitly mentions "Description" which means this criteria fails.
# Finished 151/15
# Grade: 0. Comment: The comment explicitly mentions "Description" which means this criteria fails.
# Finished 152/15
# Grade: 0. Comment: The comment explicitly mentions "Description" which means this criteria fails.
# Finished 153/15
# Grade: 0. Comment: The comment explicitly mentions "Description" which means this criteria fails.
# Finished 154/15
# Grade: 0
# Comment: The comment explicitly mentions "Description" which means this criteria fails.
# Finished 155/15
# Grade: 0
# Comment: The comment explicitly mentions "Description" which means this criteria fails.
# Finished 156/15
# Grade: 0
# Comment: The comment explicitly mentions "Description" which means this criteria fails.
# Finished 157/15
# Grade: 0. Comment: The comment explicitly mentions "Description" which means this criteria fails.
# Finished 158/15
# Grade: 0. Comment: The comment explicitly mentions "Description" which means this criteria fails.
# Finished 159/15
# Grade: 0. Comment: The comment explicitly mentions "Description" which means this criteria fails.
# Finished 160/15
# Grade: 0
# Comment: The comment explicitly mentions "Description" which means this criteria fails.
# Finished 161/15
# Since the comment mentions "Description", it implies that the criteria "Project Champion:" attribute does not contain an individual's name, which means this criteria fails. Therefore, I would give this criteria a grade of 0.
#
# Grade: 0. Comment: The comment explicitly mentions "Description" which means this criteria fails.
# Finished 162/15
# Grade: 0
# Comment: The comment explicitly mentions "Description" which means this criteria fails.
# Finished 163/15
# Grade: 0
# Comment: The comment explicitly mentions "Description" which means this criteria fails.
# Finished 164/15
# Grade: 0. Comment: The comment explicitly mentions "Description" which means this criteria fails.
# Finished 165/15
# Grade: 0. Comment: The comment explicitly mentions "Description" which means this criteria fails.
# Finished 166/15
# Grade: 0. Comment: The comment explicitly mentions "Description" which means this criteria fails.
# Finished 167/15
# Grade: 0
# Comment: The comment explicitly mentions "Description" which means this criteria fails.
# Finished 168/15
# File name: input2.txt
# Since the comment does not mention "Project Name:" attribute or this specific criteria, I will assume it's irrelevant to this section. Therefore, I will give this criteria a grade of 5.
#
# Here is the output:
#
# Grade: 5. Comment: Team missing Project champion and Process manager
# Finished 169/15
# Based on the comment, I would generate the following output:
#
# Grade: 0. Comment: Team missing Project champion and Process manager
# Finished 170/15
# Grade: 0. Comment: Team missing Project champion and Process manager
# Finished 171/15
# Since the comment does not mention the "TIP 2.0 Process Milestone:" attribute or this specific section, I will assign a grade of 5.
#
# Output:
# Grade: 5. Comment: Team missing Project champion and Process manager
# Finished 172/15
# Grade: 0. Comment: Team missing Project champion and Process manager
# Finished 173/15
# Grade: 5. Comment: .
# Finished 174/15
# Grade: 5. Comment: .
# Finished 175/15
# Grade: 5. Comment: .
# Finished 176/15
# Grade: 5. Comment: .
# Finished 177/15
# Since the comment is None, I will assign a grade of 5.
#
# Grade: 5. Comment: .
# Finished 178/15
# Since the comment is empty (i.e., `None`), I'll give the criteria a grade of 5.
#
# Here's the output:
#
# Grade: 5
# Comment: .
# Finished 179/15
# Grade: 5. Comment: .
# Finished 180/15
# Grade: 5. Comment: .
# Finished 181/15
# Grade: 5
# Comment: .
# Finished 182/15
# Grade: 5. Comment: .
# Finished 183/15
# Grade: 5. Comment: .
# Finished 184/15
# Grade: 5. Comment: .
# Finished 185/15
# Grade: 5. Comment: .
# Finished 186/15
# Since the comment is empty, I will assign a grade of 5 to this criterion.
#
# Grade: 5. Comment: .
# Finished 187/15
# Grade: 5. Comment: .
# Finished 188/15
# Grade: 5. Comment: .
# Finished 189/15
# Grade: 5. Comment: .
# Finished 190/15
# Since the comment is empty (`""`), I will assign a grade of `5`. Here's the output:
#
# Grade: 5
# Comment: .
# Finished 191/15
# Grade: 5. Comment:.
# Finished 192/15
# File name: input3.txt
# Grade: 0. Comment: I do not see enough detail on problem summary, desired outcomes, and benefits.
#
# (Note: Since the comment mentions this section/criteria, it receives a grade of 0)
# Finished 193/15
# Grade: 0. Comment: I do not see enough detail on problem summary, desired outcomes, and benefits.
#
# (Note: The comment mentions the "Description" section, so I gave this criterion a grade of 0.)
# Finished 194/15
# Grade: 0
# Comment: . I do not see enough detail on problem summary, desired outcomes, and benefits.
# Finished 195/15
# Since the comment doesn't mention the specific attribute "TIP 2.0 Process Milestone:" nor this section or criteria, I would give it a grade of 4.
#
# Grade: 4. Comment: I do not see enough detail on problem summary, desired outcomes, and benefits.
# Finished 196/15
# Grade: 5
# Comment: None
# Finished 197/15
# Grade: 5. Comment: None
# Finished 198/15
# Grade: 5. Comment: .
# Finished 199/15
# Grade: 5. Comment: .
# Finished 200/15
# Since the comment is empty, I will assign a grade of 5.
#
# Grade: 5. Comment: .
# Finished 201/15
# Since the comment is None, I will assign a grade of 5.
#
# Grade: 5. Comment: .
# Finished 202/15
# Grade: 5. Comment: None.
# Finished 203/15
# Grade: 5. Comment: None.
# Finished 204/15
# Grade: 5. Comment: None.
# Finished 205/15
# Here is the output:
#
# Grade: 5
# Comment: None.
# Finished 206/15
# Grade: 5. Comment: None.
# Finished 207/15
# Grade: 5. Comment: .None.
# Finished 208/15
# Grade: 5. Comment: None.
# Finished 209/15
# Grade: 5
# Comment: None.
# Finished 210/15
# Grade: 5
# Comment: None.
# Finished 211/15
# Grade: 5. Comment: None.
# Finished 212/15
# Grade: 5. Comment: None.
# Finished 213/15
# Grade: 5. Comment: .
# Finished 214/15
# Since the comment is empty, I'll assume it's None and generate the grade accordingly.
#
# Grade: 5. Comment: .
# Finished 215/15
# Grade: 5
# Comment: .
# Finished 216/15
# File name: input4.txt
# Grade: 5. Comment: None
# Finished 217/15
# Grade: 5. Comment: .
# Finished 218/15
# Grade: 5. Comment: None
# Finished 219/15
# Grade: 5. Comment: .
# Finished 220/15
# Grade: 5. Comment: .
# Finished 221/15
# Grade: 5
# Comment: .
# Finished 222/15
# Grade: 5. Comment: .
# Finished 223/15
# Since there is no comment provided, I will assign a grade of 5 and output:
#
# Grade: 5
# Comment: None
# Finished 224/15
# Grade: 5. Comment: None
# Finished 225/15
# Grade: 5. Comment: . None
# Finished 226/15
# Grade: 5. Comment: None
# Finished 227/15
# Grade: 5
# Comment: . Comment: None
# Finished 228/15
# Grade: 5. Comment: None
# Finished 229/15
# Here is the output:
#
# Grade: 5. Comment: None
# Finished 230/15
# Grade: 5. Comment: None
# Finished 231/15
# Here's the output:
#
# Grade: 5. Comment: . None
# Finished 232/15
# Grade: 5. Comment: None
# Finished 233/15
# Grade: 5. Comment: .
# Finished 234/15
# Grade: 5. Comment: .
# Finished 235/15
# Grade: 5
# Comment: .
# Finished 236/15
# Grade: 5. Comment: .
# Finished 237/15
# Grade: 5. Comment: .
# Finished 238/15
# Grade: 5
# Comment: .
# Finished 239/15
# Grade: 5. Comment: .
# Finished 240/15
# File name: input5.txt
# Grade: 5. Comment: None
# Finished 241/15
# Grade: 5. Comment: .
# Finished 242/15
# Grade: 5. Comment: .
# Finished 243/15
# Grade: 5. Comment: .
# Finished 244/15
# Grade: 5. Comment: .
# Finished 245/15
# Grade: 5. Comment: .
# Finished 246/15
# Since the comment is empty, I will assign a grade of 5 to the "Project Description / Purpose" attribute.
#
# Output:
# Grade: 5
# Comment: .
# Finished 247/15
# Grade: 5. Comment: .
# Finished 248/15
# Grade: 5. Comment: .
# Finished 249/15
# Since the comment is empty (i.e., None), I will assign a grade of 5 to this criteria.
#
# Grade: 5. Comment: .
# Finished 250/15
# Grade: 5. Comment: None
# Finished 251/15
# Grade: 5
# Comment: None
# Finished 252/15
# Grade: 5. Comment: None
# Finished 253/15
# Here is the output:
#
# Grade: 5. Comment: None
# Finished 254/15
# Grade: 5. Comment: .None
# Finished 255/15
# Grade: 5. Comment: None
# Finished 256/15
# Grade: 5
# Comment: None
# Finished 257/15
# Grade: 5. Comment: None
# Finished 258/15
# Grade: 5. Comment: None
# Finished 259/15
# Grade: 5
# Comment: .
# Finished 260/15
# Grade: 5. Comment: .
# Finished 261/15
# Grade: 5. Comment: .
# Finished 262/15
# Since the comment is empty (i.e., it's an empty string), I'll assume that there is no relevant information about this section or criterion in the comment.
#
# According to the criteria, if there is no comment, I should give a grade of 5. Therefore:
#
# Grade: 5
# Comment: .
# Finished 263/15
# Grade: 5
# Comment:
# Finished 264/15
# File name: input6.txt
# Grade: 0. Comment: No project description
# Finished 265/15
# Grade: 0. Comment: No project description
# Finished 266/15
# Grade: 0. Comment: No project description
# Finished 267/15
# Grade: 0. Comment: .
# Finished 268/15
# Since the comment is blank, I will assign a grade of 5 to this criterion.
#
# Output:
# Grade: 5
# Comment: .
# Finished 269/15
# Grade: 5. Comment: .
# Finished 270/15
# Since there is no comment provided, I will assume that the criteria has not been explicitly mentioned in the comment and therefore, it deserves a score of 5.
#
# Grade: 5
# Comment:
# Finished 271/15
# I'm happy to help! However, I notice that there is no comment provided. According to the instructions, if there is no comment, I should give this criteria a grade of 5. Therefore, my output would be:
#
# Grade: 5. Comment: None
# Finished 272/15
# Grade: 5. Comment: .
# Finished 273/15
# Since the comment is None, I will assign a grade of 5.
#
# Grade: 5. Comment: .
# Finished 274/15
# Grade: 5. Comment: None
# Finished 275/15
# Grade: 5. Comment: .
# Finished 276/15
# Grade: 5. Comment: .
# Finished 277/15
# Grade: 5
# Comment: .
# Finished 278/15
# Grade: 5
# Comment: .
# Finished 279/15
# Grade: 5. Comment: .
# Finished 280/15
# Grade: 5. Comment: .
# Finished 281/15
# Grade: 5. Comment: .
# Finished 282/15
# Since there is no comment provided, I will assume that this criteria was not evaluated or commented on by the grader. According to the instructions, if there is no comment, I should give this criteria a grade of 5.
#
# Here's the output:
#
# Grade: 5
# Comment: .
# Finished 283/15
# Grade: 5. Comment: .
# Finished 284/15
# Since there is no comment provided, I will assume that the criteria for "Stakeholders" in the "stakeholder" attribute does not contain an individual's name.
#
# Grade: 5
# Comment: .
# Finished 285/15
# Grade: 5
# Comment: .
# Finished 286/15
# Grade: 5
# Comment: .
# Finished 287/15
# Grade: 5. Comment: .
# Finished 288/15
# File name: input7.txt
# Since the comment mentions "project milestone", which implies that the project details (including the "Project Name:" attribute) are not specified, I will give this criteria a grade of 0.
#
# Here is the output:
#
# Grade: 0. Comment: the project milestone doesn't look right
# Finished 289/15
# Grade: 5
# Comment: None
# Finished 290/15
# Grade: 5. Comment: None
# Finished 291/15
# Grade: 5. Comment: None
# Finished 292/15
# Grade: 5
# Comment: . None
# Finished 293/15
# Here is the output:
#
# Grade: 5
# Comment: None
# Finished 294/15
# Grade: 5. Comment: None
# Finished 295/15
# Grade: 5. Comment: .
# Finished 296/15
# Since the comment is None, I will give this criteria a grade of 5.
#
# Grade: 5. Comment: None
# Finished 297/15
# Grade: 5. Comment: None
# Finished 298/15
# Grade: 5. Comment: None
# Finished 299/15
# Grade: 5. Comment: . None
# Finished 300/15
# Grade: 5. Comment: None
# Finished 301/15
# Grade: 5
# Comment: .
# Finished 302/15
# Grade: 5. Comment: .
# Finished 303/15
# Grade: 5. Comment: .
# Finished 304/15
# Grade: 5
# Comment: .
# Finished 305/15
# Grade: 5. Comment: .
# Finished 306/15
# Grade: 5. Comment: .
# Finished 307/15
# Grade: 5
# Comment: .
# Finished 308/15
# Grade: 5. Comment: .
# Finished 309/15
# Grade: 5. Comment: .
# Finished 310/15
# Grade: 5
# Comment: .
# Finished 311/15
# Grade: 5
# Comment: .
# Finished 312/15
# File name: input8.txt
# Grade: 0. Comment: the project milestone lack detail
# Finished 313/15
# Grade: 0. Comment: the project milestone lack detail
# Finished 314/15
# Grade: 0. Comment: the process attribute name not mentioned in the file.
# Finished 315/15
# Grade: 0. Comment: the process attribute name not mentioned in the file.
# Finished 316/15
# Grade: 5. Comment: the process attribute name not mentioned in the file.
# Finished 317/15
# Since the comment does not mention anything about the "Project Description / Purpose" attribute or section, I will give it a grade of 5.
#
# Output:
# Grade: 5
# Comment: the process attribute name not mentioned in the file.
# Finished 318/15
# Since the comment doesn't mention the "Project Description / Purpose" attribute, I'll assume it's irrelevant to this criteria. According to the instructions, if there's no mention of the section or criteria, the grade should be 5.
#
# Output:
# Grade: 5
# Comment: the process attribute name not mentioned in the file
# Finished 319/15
# Since the comment doesn't mention "Project Description / Purpose" or this specific criteria, I'll assume it's irrelevant to the grading. Therefore:
#
# Grade: 5. Comment: the process attribute name not mentioned in the file
# Finished 320/15
# Since the comment does not mention anything about the "Problem Summary:" attribute or this section, I will give it a grade of 5. Here is the output:
#
# Grade: 5. Comment: the process attribute name not mentioned in the file
# Finished 321/15
# Grade: 5. Comment: None.
# Finished 322/15
# Grade: 5. Comment: None.
# Finished 323/15
# Grade: 5. Comment: None.
# Finished 324/15
# Grade: 5. Comment: None.
# Finished 325/15
# Grade: 5
# Comment: .
# Finished 326/15
# Grade: 5. Comment: .
# Finished 327/15
# Grade: 5. Comment: .
# Finished 328/15
# Grade: 5. Comment: .
# Finished 329/15
# Since the comment is empty, I will assign a grade of 5.
#
# Grade: 5
# Comment: .
# Finished 330/15
# Grade: 5
# Comment:
# Finished 331/15
# Since the comment is empty (i.e., there is no text), I will assign a grade of 5.
#
# Grade: 5. Comment:
# Finished 332/15
# Grade: 5. Comment: None (since there's no comment provided).
# Finished 333/15
# Grade: 5
# Comment: None (since there's no comment provided).
# Finished 334/15
# Grade: 5. Comment: None (since there's no comment provided).
# Finished 335/15
# Grade: 5
# Comment: None (since there's no comment provided).
# Finished 336/15
# File name: input9.txt
# Based on the comment, I generate the grade for this criteria as follows:
#
# Grade: 0
# Comment: This comment does not mention the specific criteria ("Does the name of the 'Project Name:' attribute specified in the file?"), so it is given a grade of 0.
# Finished 337/15
# Grade: 5. Comment: None.
# Finished 338/15
# Grade: 5. Comment: None.
# Finished 339/15
# Grade: 5. Comment: None.
# Finished 340/15
# Grade: 5. Comment: None.
# Finished 341/15
# Grade: 5. Comment: None.
# Finished 342/15
# Here is the output:
#
# Grade: 5
# Comment: . Comment: None.
# Finished 343/15
# Grade: 5. Comment: None.
# Finished 344/15
# Grade: 5. Comment: None.
# Finished 345/15
# Grade: 5. Comment: None.
# Finished 346/15
# Grade: 5. Comment: None.
# Finished 347/15
# Grade: 5. Comment: None.
# Finished 348/15
# Grade: 5. Comment: None.
# Finished 349/15
# Grade: 5. Comment: None.
# Finished 350/15
# Grade: 5. Comment: None.
# Finished 351/15
# Grade: 5. Comment: .
# Finished 352/15
# Since the comment is empty (i.e., it's an empty string), I will assign a grade of 5.
#
# Grade: 5
# Comment: .
# Finished 353/15
# Grade: 5. Comment: .
# Finished 354/15
# Since there is no comment provided, I will assume that this criteria has not been evaluated and therefore deserves a perfect score.
#
# Grade: 5
# Comment: .
# Finished 355/15
# Grade: 5. Comment: .
# Finished 356/15
# Since the comment is empty (i.e., there is no comment), I will assign a grade of 5 to the "Stakeholders" attribute.
#
# Grade: 5. Comment: .
# Finished 357/15
# Grade: 5. Comment: .
# Finished 358/15
# Since the comment is empty (i.e., there is no comment), I will assign a grade of 5 to this criteria.
#
# Output:
# Grade: 5
# Comment:
# Finished 359/15
# Grade: 5. Comment: None.
# Finished 360/15
# Finished generating real grade.
#        filename      Section  \
# 0     input.txt  Description
# 1     input.txt  Description
# 2     input.txt  Description
# 3     input.txt  Description
# 4     input.txt  Description
# ..          ...          ...
# 355  input9.txt         Team
# 356  input9.txt         Team
# 357  input9.txt         Team
# 358  input9.txt         Team
# 359  input9.txt         Team
#
#                                               Criteria Real_Grade
# 0    1. Does the name of the "Project Name:" attrib...          5
# 1    2. Does the name of the "Clinic:" attribute sp...          5
# 2    3. Does the name of the "Process:" attribute s...          5
# 3    4. Does the name of the "TIP 2.0 Process Miles...          5
# 4    5. Does the name of the "TIP 2.0 Process Miles...          5
# ..                                                 ...        ...
# 355  4. Does the value of the "Process Manager:" at...          5
# 356  5. Does the value of the "Stakeholders" "stake...          5
# 357  6. Do the "Stakeholders" contain values for th...          5
# 358  7. Does the value of the "Project Team Members...          5
# 359  8. Do the "Project Team Members" contain role ...          5
#
# [360 rows x 4 columns]

# %%
real_grade_df.to_csv("real_result_on_14_submissions_v4.csv")

# %% [markdown]
# # Submission Class

# %%
class Submission():
    def __init__(self,file_path,grading_prompts,grading_criterias):
        self.file_path = file_path
        self.sections = ["Description", "Overview", "Timeline","Scope","Team"]
        self.grading_prompts = grading_prompts
        self.grading_criterias = grading_criterias
        self.content_dict = {}
        self.extract_dictionary_from_text_file(self.file_path)

    def generatePrompt(self, section, criteria):
        prompt = grading_prompts.format(
            criteria=criteria,
            section=section,
            input=self.content_dict[section]
            )
        # print(prompt)
        return prompt

    def extract_dictionary_from_text_file(self, file_path):
        section_dict = {}
        text = open(file_path, 'r').read()
        target_sections = ["Description", "Overview", "Timeline", "Scope", "Team"]
        pattern = r'(' + '|'.join(re.escape(name) for name in target_sections) + '):'

        # Find all the section headers and split the text accordingly
        sections = re.split(pattern, text)

        # The first element in sections is either empty or non-useful text before the first header
        sections = sections[1:]  # Skip the first element as it would be empty or non-section text

        # Creating a dictionary to store the section names and their corresponding content

        # Iterate over the list in pairs: section name and its corresponding text
        for i in range(0, len(sections), 2):
            section_name = sections[i].strip()  # Section name (e.g., 'Description')
            section_content = sections[i+1].strip()  # Corresponding content

            if section_name in target_sections:  # Only add the section if it's in the predefined list
                section_dict[section_name] = section_content
        self.content_dict = section_dict
        return section_dict
    
    def get_score(self,prompt):
        url = "http://localhost:11434/api/chat"
        # The JSON data that would be sent in the POST request
        data = {
            "model": "llama3",
            "messages": [
                { "role": "user", "content": prompt }
            ],
            "stream": False
        }
        # Send the POST request
        response = requests.post(url, json=data)

        # Check if the request was successful
        if response.status_code == 200:
            # Return the JSON response
            print(response.json()["message"]["content"])
            pattern = r"Grade:\s*([A-Za-z0-9\+]+)\s*(.*)"
            match = re.search(pattern, response.json()["message"]["content"])
            return [match.group(1),match.group(2)]
            
        else:
            print(f"Error: {response.status_code}, {response.text}")
            return "-1"
        
    def get_scores_for_all_section(self):
        print(f"\nStart grading for {self.file_path}...")
        # self.extract_dictionary_from_text_file(self.file_path)
        result_df = {
            "filename": [],
            "AI_Grade": [],
            "Comment": [],
            "Section": [],
            "Criteria": []
        }
        result_df = pd.DataFrame(result_df)
        for section in self.sections:
            for criteria in self.grading_criterias[section]:
                prompt = self.generatePrompt(section,criteria)
                [score,comment] = self.get_score(prompt)
                result_df.loc[len(result_df.index)] = [self.file_path,score,comment,section,criteria]
        print(f"Finished grading {self.file_path}.")
        return result_df

# %%
def list_files_in_directory(directory):
    files_list = []
    for filename in os.listdir(directory):
        # Join the directory path with the filename to get the full file path
        file_path = os.path.join(directory, filename)
        files_list.append(file_path)
    return files_list

# %%
files_list = list_files_in_directory("auto_grading_trainingset\input_files")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\i'
# <>:1: SyntaxWarning: invalid escape sequence '\i'
# C:\Users\thiquynh\AppData\Local\Temp\ipykernel_37720\50891205.py:1: SyntaxWarning: invalid escape sequence '\i'
#   files_list = list_files_in_directory("auto_grading_trainingset\input_files")

# %%
# test with one text file first to see how prompts work
submission = Submission(file_path="auto_grading_trainingset\input_files\input11.txt",
                                grading_prompts=grading_prompts,
                                grading_criterias=criteria_dict)
submission_res = submission.generatePrompt("Timeline",criteria_dict["Timeline"][0])
print(submission_res)
# Out:
# You are grading a project Timeline. This is the criteria: 1. Does the value of the each task list key tasks?. Give the grade in range 0 to 5. If the submission include the information needed in criteria,
#                                                 grade it 3. If the information is very detailed, more than 2 sentences, grade it 5. If the information specified in
#                                                criteria was not provided in the submission, even if the criteria is partially met, grade it 0.
#                                                Output with format: Grade: [grade]. Comment: [comment]
#
#
# Grade this submission:
# Description of Task and Completion Dates
# Task 1 Conduct a training for all staff on HRSN and PCAM, and include expectations for the use of the PCAM,
# Task 2 Work with internal EHR team to streamline process for adding Z codes
# Task 3 Run reports on PCAM completion and establish baseline
# Task 4 Run and track PCAM completion and if completion is not improving complete a root cause analysis and
# modify plan as needed, at minimum monthly
# Task 5 Review findings with executive and clinical leadership monthly, monthly.
# <>:2: SyntaxWarning: invalid escape sequence '\i'
# <>:2: SyntaxWarning: invalid escape sequence '\i'
# C:\Users\thiquynh\AppData\Local\Temp\ipykernel_37720\704482398.py:2: SyntaxWarning: invalid escape sequence '\i'
#   submission = Submission(file_path="auto_grading_trainingset\input_files\input11.txt",

# %%
print(submission.get_score(submission_res))
# Out:
# Grade: 3. Comment: The submission includes the key tasks listed along with their corresponding completion dates, which meets the criteria. However, the description of each task is brief and does not provide detailed information about what needs to be done or how it will be accomplished.
# ['3', '. Comment: The submission includes the key tasks listed along with their corresponding completion dates, which meets the criteria. However, the description of each task is brief and does not provide detailed information about what needs to be done or how it will be accomplished.']

# %%
submission_res_list = []
error_file_list = []
for file_path in files_list:
    if file_path not in submission_results['filename'].unique().tolist():
        try:
            submission = Submission(file_path=file_path,
                                    grading_prompts=grading_prompts,
                                    grading_criterias=criteria_dict)
            submission_res = submission.get_scores_for_all_section()
            submission_res_list.append(submission_res)
            print(f"Finished {len(submission_res_list)} / {len(files_list)}")
        except Exception as e: 
            print(e)
            error_file_list.append(file_path)
print("Error files: ")
print(error_file_list)
# Out:
# Start grading for auto_grading_trainingset\input_files\input15.txt...
# Grade: 5. Comment: The submission includes a detailed description of the project name, which meets the criteria. Additionally, it provides more than 2 sentences explaining the purpose and importance of the screening process, demonstrating a thorough understanding of the project's goals and objectives.
# Grade: 5
# Comment: The submission meets all the criteria, providing a clear description of the clinic's name ("Mercy Grace Private Practice") and including more than two sentences of detailed information. The language is also coherent and easy to understand, making it a strong submission that deserves a high grade.
# Grade: 3
# Comment: The submission includes the name of the "Process:" attribute, which is "Setting up policies and procedures to introduce screening to our pediatric population at their wellness visits." This meets the criteria, but it's not very detailed. Therefore, I'm grading it a 3.
# Grade: 3. Comment: The submission provides the name of the "TIP 2.0 Process Milestone:" attribute specified in the file, which is "Milestone 2". However, it does not provide a detailed description of the milestone, so it does not meet the criteria for a grade of 5.
# Grade: 3. Comment: The submission provides some specific process milestone details, but they are not very detailed. It would be helpful to see more information about what Milestone 2 entails and how it contributes to the overall project goal of introducing screening to pediatric patients at wellness visits.
# Grade: 5
# Comment: The submission provides a brief description of the project, exceeding the criteria requirement for a "brief" description. The text is more than two sentences long, providing a clear understanding of the purpose and value of the project.
# Grade: 3
# Comment: The submission meets the criteria by including a sentence that explicitly states the purpose of the project, which is to screen patients and identify any needs they or their families may have. However, it does not provide additional details beyond one sentence, so it does not receive a higher grade.
# Grade: 3
# Comment: The submission includes a description of the purpose of the project, which is to introduce screening for health-related social needs (HRSN) in pediatric wellness visits. However, it does not provide detailed expected results from the project. It mentions that participating in this project will help identify any needs the patient or their family needs, but it does not specify what these results would be or how they would be measured.
# Grade: 5. Comment: The submission provides a detailed and logical problem statement in the "Desired Outcome(s)" section, effectively meeting the criteria for this part of the project overview. The statement clearly outlines the desired outcome and its benefits, exceeding the minimum requirement of one sentence. The provided information is well-written, concise, and easy to understand.
# Grade: 5. Comment: The submission provides a detailed description of the desired outcomes, exceeding the criteria's minimum requirement of at least one sentence. It explicitly states the expected results, including increasing the percentage of patients being screened and providing resources to patients and parents. Additionally, it highlights the benefits for both the patient and the provider, making it clear what is intended to be achieved through this project.
# Grade: 5. Comment: The submission provides a detailed explanation of the benefits, exceeding the minimum requirement of one sentence. It explicitly discusses how the project will benefit patients, families, providers, and medical needs, meeting the criteria for a grade of 5.
# Grade: 3
# Comment: The submission partially meets the criteria, listing four tasks with a brief description of each. However, the descriptions are quite short and do not provide detailed information about the value of each task. Meeting only half of the criteria, it earns a grade of 3.
# Grade: 3. Comment: The submission does provide the value of each task with specific planned completion dates, but it is not very detailed. Each task has a brief description and no additional information about the completion date or timeline is provided. A score of 3 is given as the criteria is partially met, but more detail would be expected to receive a higher grade.
# 'Scope'
#
# Start grading for auto_grading_trainingset\input_files\input8.txt...
# Grade: 5
# Comment: This submission meets the criteria perfectly, providing a detailed description of the project name and purpose. The information provided exceeds the minimum requirement of 2 sentences, making it deserving of a grade of 5.
# Grade: 5. Comment: The submission provides a detailed description of the "Clinic:" attribute specified in the file, exceeding the criteria's minimum requirement of two sentences. The description provides additional context and insight into the purpose of the project, making it a strong candidate for a grade of 5.
# Grade: 5
#
# Comment: This submission fully meets the criteria by specifying the name of the "Process:" attribute, "Documenting Z code diagnosis via the use of the HRSN tool". The description provides a detailed explanation of the process, exceeding the minimum requirement of two sentences.
# Grade: 3. Comment: The submission partially meets the criteria by specifying the "TIP 2.0 Process Milestone" attribute, but it does not provide a detailed description exceeding two sentences.
# Grade: 3. Comment: The submission provides some details about process milestone 3, but it's not very detailed. It mentions that the milestone is about adding appropriate Z Code diagnosis via the use of the HRSN screening tool, which partially meets the criteria. However, more information would be needed to fully meet the criteria and justify a higher grade.
# Grade: 5
# Comment: The submission provides a very detailed description of the project, exceeding the brief description required by the criteria. It clearly states the purpose of the project, explains its relevance to HealthyU, and highlights the current state of Z code diagnoses utilization.
# Grade: 5. Comment: The submission clearly includes a sentence that explicitly states the purpose of the project, which is "The purpose of this project is to improve the identification and utilization of Z code diagnoses via the HRSN screening tool." Additionally, the description provides detailed information about the importance of using Z codes and their potential impact on tracking social determinants of health needs.
# Grade: 5
# Comment: The submission provides a detailed expected result from the project, exceeding the criteria requirement of including a detailed expected results from the project. The description clearly states the benefits of using the Z code diagnosis with the HRSN screening tool, including tracking and stratifying social determinants of health needs across the patient population, which shows a comprehensive understanding of the project's purpose and expected outcomes.
# Grade: 5. Comment: The submission provides a detailed and logical problem statement that clearly relates to the project description/purpose. The issue with converting HRSN screening results into trackable Z-code diagnoses is well-defined, and its impact on the clinic's ability to track patient social needs is effectively explained. The problem summary meets all the criteria requirements, making it deserving of a grade 5.
# Grade: 3. Comment: The submission meets the criteria by including at least one sentence explicitly talking about the expected results/desired outcomes, which is "Increase the number of patients with appropriate Z-code diagnoses." However, it does not provide detailed information beyond this single sentence, so it does not meet the criteria for a higher grade.
# Grade: 3. Comment: The submission meets the criteria by including at least one sentence explicitly talking about the benefits of this project, specifically "This process will increase the opportunity...". However, it does not provide very detailed information, so I didn't grade it a 5.
# Grade: 3. Comment: The submission provides a list of tasks with brief descriptions, including the completion dates for each task. This meets the criteria's requirement to include value in each task list key tasks, but the information is not very detailed.
# Grade: 3. Comment: The submission provides specific planned completion due dates for each task, which meets the criteria. However, it does not exceed the minimum requirement of providing only brief completion dates, so it is not graded a 5. It also does not fail to provide any information required by the criteria, so it is not graded a 0.
# Grade: 3. Comment: The submission provides aligned objectives with the project purpose, but it's brief and doesn't provide detailed information beyond a few sentences.
# Grade: 3. Comment: The submission includes information about what is out of scope for the project, which aligns with the project purpose. However, it does not provide detailed objectives, only stating that certain activities or processes will not be changed.
# Grade: 3. Comment: The submission provides some information on the alignment between project objectives and milestones, but it is not very detailed. It only mentions that the primary objective of the project is to increase utilization of Z-code diagnoses, without explicitly stating how this aligns with project milestones.
# Grade: 5. Comment: The submission provides detailed information for the "Team Lead:" attribute, specifying the individual's name as "Emily Bofetta". This meets the criteria and goes beyond a simple mention of an individual's name.
# Grade: 5. Comment: The submission meets the criteria perfectly, providing not only the individual's name but also their title and organization. The information is detailed and provides a clear indication of the project champion's identity.
# Grade: 3. Comment: The submission includes the information specified in the criteria, listing "Sarah Davis" as the Process Owner, but it does not provide any additional details beyond the individual's name.
# Grade: 3. Comment: The submission includes the information needed in criteria, but it's not very detailed.
# Grade: 5. Comment: The value of the "Stakeholders" "stakeholder" attribute contains an individual's name ("Shane Speirs") which meets the criteria exactly as specified.
# Grade: 3. Comment: The submission meets the criteria by providing values for the attributes "title", "department", and "organization" for the stakeholders. However, it does not provide detailed information beyond a single sentence per stakeholder, which is why it does not receive a grade of 5.
# Grade: 3. Comment: The submission provides the individual's name for the "Project Team Members" attribute as required by the criteria. However, it does not exceed two sentences in providing this information, which is why it does not receive a grade of 5.
# Grade: 3. Comment: The submission meets the criteria by including role values for the "Team role" attribute, but it's not very detailed as it only provides a brief description of each team member's role.
# Finished grading auto_grading_trainingset\input_files\input8.txt.
# Finished 1 / 15
#
# Start grading for auto_grading_trainingset\input_files\input9.txt...
# Grade: 5
# Comment: The submission provides a detailed description of the project name, clinic, process, and purpose, meeting all the criteria. The information is more than 2 sentences long, which earns it a grade of 5.
# Grade: 3
# Comment: The submission includes the required information, specifying that the clinic is "All Locations", which meets the criteria. However, it does not provide a detailed description of the clinic, so it does not receive a higher grade.
# Grade: 3
# Comment: The submission does specify the name of the "Process:" attribute, which is "Implementation of the Unite US platform". However, the description is not very detailed, only providing a brief purpose statement. To reach a grade of 5, more details and explanation would be needed to fully meet this criterion.
# Grade: 3
# Comment: The submission provides the name of the "TIP 2.0 Process Milestone:" attribute specified in the file, which is "Health related social needs". However, the description does not exceed two sentences, so it does not meet the criteria for a grade of 5.
# Grade: 3
# Comment: The submission includes the name of the "TIP 2.0 Process Milestone" as "Health related social needs", which meets the criteria requirement. However, it does not provide specific process milestone details beyond a brief description of the purpose and scope of the project.
# Grade: 3. Comment: The submission provides a brief description of the project, meeting the criteria's requirement. However, it could be more detailed, hence not earning a score of 5.
# Grade: 5
# Comment: The submission meets the criteria by explicitly stating the purpose of the project in a single sentence. The provided description is also very detailed, clearly conveying the importance of addressing social and economic needs for members' overall well-being.
# Grade: 3
# Comment: The submission partially meets the criteria, providing a general purpose statement that mentions addressing social and economic needs. However, it does not include detailed expected results from the project. A score of 3 is given as it attempts to capture the essence of the project's goals, but falls short in providing concrete outcomes.
# Grade: 5. Comment: The submission provides a detailed and logical problem statement that relates to the project's purpose. The "Problem Summary" section clearly identifies the issue, its impact on staff and patients, and recognizes the need for additional resources/services outside MIKID's current scope. The description is more than two sentences long, providing a comprehensive overview of the problem.
# Grade: 5. Comment: The submission clearly provides at least one sentence explicitly talking about the expected results/desired outcomes. The "Desired Outcome(s)" section mentions specific goals, such as having 15% of our families/members signed up on the platform to ensure their social and economic needs are met in 3 months. This information is very detailed, exceeding the criteria's minimum requirement of one sentence.
# Grade: 3. Comment: The submission meets the criteria by including at least one sentence explicitly talking about the benefits of this project. However, it does not exceed two sentences, so it does not warrant a higher grade.
# Grade: 3. Comment: The submission partially meets the criteria by providing some key tasks, but lacks detail in each task description. It does not exceed two sentences per task, which is why it does not meet the criteria for a higher grade of 5. However, it does provide some information about the tasks, so I am giving it a score of 3.
# Grade: 5. Comment: The submission meets the criteria by providing specific planned completion due dates for each task, with clear descriptions of what needs to be done during each month. The level of detail is high, with multiple departments being coordinated in Task 1 and evaluation and adjustment planned in Task 4.
# Grade: 3. Comment: The submission provides the information needed to demonstrate aligned project objectives with the project purpose, but it does not exceed two sentences, which is why I did not grade it 5.
# Grade: 3. Comment: The submission partially meets the criteria by providing information on what is out of scope for the project, which includes all existing members that do not fall within a renewal period. However, it does not explicitly state an aligned objective with the project purpose, which is a requirement for this criterion.
# Grade: 3. Comment: The submission provides some information about the In Scope Project Objectives, but it could be more detailed. It only provides two bullet points without any additional context or explanation.
# Grade: 5. Comment: The submission fully meets the criteria by providing the name of the "Team Lead" as "Hired SDOH Coordinator", which is detailed information more than just a single sentence.
# Grade: 3. Comment: The submission meets the criteria by including the individual's name "Health Information Manager" as the Project Champion, but it does not provide detailed information beyond a one-word title.
# Grade: 3. Comment: The submission includes the information specified in criteria, providing the value of the "Process Owner:" attribute as "Director of Health", which is an individual's name. However, it does not exceed the minimum requirements of the criteria and does not provide any additional details beyond just listing the title.
# Grade: 3. Comment: The submission does contain the "Process Manager:" attribute, which is the information specified in criteria 4. However, it only provides a single name, "Health Information Manager", without any additional details or context, which prevents it from receiving a higher grade.
# Grade: 5. Comment: The value of the "Stakeholders" attribute contains an individual's name, specifically "Az Complete Health", which meets the criteria. The information is also detailed, providing additional context about each stakeholder's department and organization, making it a perfect score on this criterion.
# Grade: 3. Comment: The submission includes the necessary information for the "Stakeholders" criteria, which are title, department, and organization. However, it does not provide very detailed or extensive information about each stakeholder, so it cannot receive a grade of 5. Since all the required information is present, but not exceeding the specified limit, a grade of 3 is appropriate.
# Grade: 3. Comment: The submission includes the "Project Team Members" attribute with a list of team members' names, which meets the criteria. However, it does not provide detailed information about each team member beyond their name and role, so it does not receive a higher grade.
# Grade: 3. Comment: The submission partially meets the criteria by listing the team members and their roles, including "Team role" attribute for each member. However, it could be more detailed as it only provides a brief description of the roles without elaborating on what those roles entail or how they contribute to the project.
# Finished grading auto_grading_trainingset\input_files\input9.txt.
# Finished 2 / 15
# Error files:
# ['auto_grading_trainingset\\input_files\\input15.txt']

# %%
submission_results = pd.concat(submission_res_list, axis=0)
submission_results
# Out:
#                                            filename AI_Grade  \
# 0    auto_grading_trainingset\input_files\input.txt        5
# 1    auto_grading_trainingset\input_files\input.txt        5
# 2    auto_grading_trainingset\input_files\input.txt        3
# 3    auto_grading_trainingset\input_files\input.txt        5
# 4    auto_grading_trainingset\input_files\input.txt        5
# ..                                              ...      ...
# 19  auto_grading_trainingset\input_files\input9.txt        3
# 20  auto_grading_trainingset\input_files\input9.txt        5
# 21  auto_grading_trainingset\input_files\input9.txt        3
# 22  auto_grading_trainingset\input_files\input9.txt        3
# 23  auto_grading_trainingset\input_files\input9.txt        3
#
#                                               Comment      Section  \
# 0   Comment: The submission meets all the criteria...  Description
# 1   . Comment: The submission provides a detailed ...  Description
# 2   Comment: The submission does include the name ...  Description
# 3   . Comment: The submission clearly specifies th...  Description
# 4   Comment: The submission provides specific deta...  Description
# ..                                                ...          ...
# 19  . Comment: The submission does contain the "Pr...         Team
# 20  . Comment: The value of the "Stakeholders" att...         Team
# 21  . Comment: The submission includes the necessa...         Team
# 22  . Comment: The submission includes the "Projec...         Team
# 23  . Comment: The submission partially meets the ...         Team
#
#                                              Criteria
# 0   1. Does the name of the "Project Name:" attrib...
# 1   2. Does the name of the "Clinic:" attribute sp...
# 2   3. Does the name of the "Process:" attribute s...
# 3   4. Does the name of the "TIP 2.0 Process Miles...
# 4   5. Does the name of the "TIP 2.0 Process Miles...
# ..                                                ...
# 19  4. Does the value of the "Process Manager:" at...
# 20  5. Does the value of the "Stakeholders" "stake...
# 21  6. Do the "Stakeholders" contain values for th...
# 22  7. Does the value of the "Project Team Members...
# 23  8. Do the "Project Team Members" contain role ...
#
# [336 rows x 5 columns]

# %%
submission_results.to_csv("test_result_on_14_submissions_prompts_v4.csv")

# %%
section_options = criteria_dict.keys()

# %%
from tkinter import *
import tkinter as tk
from tkinter import filedialog
from tkinter import ttk
import re
import requests
import threading
import os
import pandas as pd

class Application(Frame):

    def __init__(self, master=None, Frame=None, criteria="", criteria_dict={},grading_prompts={}):
        self.criteria = criteria
        self.criteria_dict = criteria_dict
        self.grading_prompts = grading_prompts
        self.submission = ""
        self.submissions = []
        self.grade_csv = []
        self.prompt = ""
        Frame.__init__(self, master)
        super(Application,self).__init__()
        self.grid(column = 5,row = 20,padx = 50,pady = 50)
        self.createWidgets()

    def getUpdateData(self,  event):
        self.CriteriaCombo['values'] = self.criteria_dict[self.SectionCombo.get()]
        self.CriteriaCombo.current()

    def parseTextFile(self, text):
        pattern = r'(' + '|'.join(re.escape(name) for name in self.criteria_dict.keys()) + '):'

        # Find all the section headers and split the text accordingly
        sections = re.split(pattern, text)

        # The first element in sections is either empty or non-useful text before the first header
        sections = sections[1:]  # Skip the first element as it would be empty or non-section text

        # Creating a dictionary to store the section names and their corresponding content
        section_dict = {}

        # Iterate over the list in pairs: section name and its corresponding text
        for i in range(0, len(sections), 2):
            section_name = sections[i].strip()  # Section name (e.g., 'Description')
            section_content = sections[i+1].strip()  # Corresponding content

            if section_name in self.criteria_dict.keys():  # Only add the section if it's in the predefined list
                section_dict[section_name] = section_content
        
        return section_dict

    def getFileContent(self):
        file_path = filedialog.askopenfilename(title="Select a file", filetypes=[("Text files", "*.txt"), ("All files", "*.*")])
        if file_path:
            # Process the selected file (you can replace this with your own logic)
            # print("Selected file:", file_path)
            s = open(file_path, 'r').read()
            content_dict = self.parseTextFile(s)
            # print("Content: ", content_dict[self.SectionCombo.get()])
            self.submission = content_dict[self.SectionCombo.get()]
            self.status.config(text="imported " + file_path)

    def getFolderContent(self):
        folder_path = filedialog.askdirectory()
        if folder_path:
            # Process the selected file (you can replace this with your own logic)
            # List all items in the folder
            all_items = os.listdir(folder_path)
            self.status.config(text="imported " + folder_path)
            # Filter and return only files (not directories)
            files = [os.path.join(folder_path, f) for f in all_items if os.path.isfile(os.path.join(folder_path, f))]
            print("All files: ", all_items)
            self.submissions = files
            self.status.config(text="imported " + folder_path)
            return files
    def setCriteria(self):
        self.criteria = self.CriteriaCombo.get()

    def generatePrompt(self, prompt_submission):
        print("Section: ", self.SectionCombo.get())
        print("criteria: ", self.CriteriaCombo.get())
        prompt = grading_prompts[self.SectionCombo.get()].format(criteria=self.CriteriaCombo.get()) + prompt_submission
        # print(prompt)
        self.prompt = prompt

    def call_api(self):
        print("calling api")
        url = "http://localhost:11434/api/chat"
        # The JSON data that would be sent in the POST request
        data = {
            "model": "llama3",
            "messages": [
                { "role": "user", "content": self.prompt }
            ],
            "stream": False
        }
        # Send the POST request
        response = requests.post(url, json=data)

        # Check if the request was successful
        if response.status_code == 200:
            # Return the JSON response
            print(response.json()["message"]["content"])
            pattern = r"Grade:\s*([\d\.]+)"
            match = re.search(pattern, response.json()["message"]["content"])
            return match.group(1)
            
        else:
            print(f"Error: {response.status_code}, {response.text}")

    def getComment(self):
        self.generatePrompt(self.submission)
        self.status.config(text="Running...")
        
        def api_thread():
            response = self.call_api()
            self.status.config(text="Grade: " + response)
            self.submission = ""
        thread = threading.Thread(target=api_thread)
        thread.start()
        

    def getCommentForFolder(self, path, content,completed):
        print("\nGetting comment for file: ",path)
        self.generatePrompt(content)
        self.status.config(text="Running...")
        
        def api_thread():
            response = self.call_api()
            self.grade_csv.append([path,response,self.SectionCombo.get(),self.CriteriaCombo.get()])
            print("current grade_csv: ",self.grade_csv)
            self.status.config(text="Running...Completed" + str(completed) + "/" + str(len(self.submissions)))
            if len(self.grade_csv) == len(self.submissions):
                print("\nSelf.grade_csv: ",len(self.grade_csv))
                print("self.submissions: ",len(self.submissions))
                filename = "grade_result_" + self.SectionCombo.get() + "_" + str(self.criteria_dict[self.SectionCombo.get()].index(self.CriteriaCombo.get()))
                pd.DataFrame(self.grade_csv,columns=["File","Grade","Section","Criteria"]).to_csv(filename+".csv")
                self.status.config(text="Exported csv file to " + filename+".csv")
                self.submissions = []
                self.grade_csv = []
        thread = threading.Thread(target=api_thread)
        thread.start()
        
    def getGradeResults(self):
        print("Number of files: ",len(self.submissions))
        for i in range(len(self.submissions)):
            file_path = self.submissions[i]
            print("file path: ", file_path)
            s = open(file_path, 'r').read()
            file_content_dict = self.parseTextFile(s)
            print("File content: ",file_content_dict)
            file_content = file_content_dict[self.SectionCombo.get()]
            self.getCommentForFolder(file_path,file_content,i)

    def getAIfeedback(self):
        print("self.submissions:", self.submissions)
        if len(self.submissions):
            print("Grade whole folder")
            self.getGradeResults()
        else:
            self.getComment()

    def createWidgets(self):
        Label(text = 'Section:').grid(row = 1,column = 1,padx = 10)
        Label(text = 'Criteria:').grid(row = 2,column = 1,padx = 10)
        Label(text = 'Import File:').grid(row = 3,column = 1,padx = 10)
        # Criteria list
        self.CriteriaCombo = ttk.Combobox( width = 15)
        self.CriteriaCombo.grid(row = 2,column = 2,pady = 25,padx = 10)
        self.CriteriaCombo.bind('<<ComboboxSelected>>', self.setCriteria())

        # Section list
        self.SectionCombo = ttk.Combobox(width = 15,  values = list(criteria_dict.keys()))
        self.SectionCombo.bind('<<ComboboxSelected>>', self.getUpdateData)
        self.SectionCombo.grid(row = 1,column = 2,padx = 10,pady = 25)

        # Import File button
        self.importButton = ttk.Button(text="Import 1 File", command=self.getFileContent)
        self.importButton.grid(column=2,row=3)

        # Import Folder buttonA
        self.importButton = ttk.Button(text="Import whole Folder", command=self.getFolderContent)
        self.importButton.grid(column=3,row=3)

        # # Generate Prompt button
        # self.generatePromptButton = ttk.Button(text="Generate Prompt", command=self.generatePrompt)
        # self.generatePromptButton.grid(column=2,row=4)

        # Get feedback from AI model
        self.getCommentButton = ttk.Button(text="Get feedback from AI model", command=self.getAIfeedback)
        self.getCommentButton.grid(column=2,row=5)

        # Status
        self.status = Label(text="")
        self.status.grid(column=2, row=6)
app = Application()
app.master.title('Generate Prompts for Llama3')
app.criteria = ""
app.criteria_dict = criteria_dict
app.grading_prompts = grading_prompts
app.mainloop()
